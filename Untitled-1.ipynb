# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:/PROJECT WITH SUJAL/Titanic - Machine Learning from Disaster/Titanic_ML_Disaster/train.csv")
test_df = pd.read_csv("D:/PROJECT WITH SUJAL/Titanic - Machine Learning from Disaster/Titanic_ML_Disaster/test.csv")

# %% [markdown]
# ###GENDER DIFFERENCE###

# %%
women = df.loc[df.Sex == "female" ][ "Survived"]
women_survived = sum(women)/len(women)
print(women_survived)
# Out:
# 0.7420382165605095

# %%
men = df.loc[df.Sex == "male" ][ "Survived"]
men_survived = sum(men)/len(men)
print(men_survived)
# Out:
# 0.18890814558058924

# %% [markdown]
# ###Class Survived###

# %%
class1 = df.loc[df.Pclass == 1 ][ "Survived"]
class1_survived = sum(class1)/len(class1)
print(class1_survived)
# Out:
# 0.6296296296296297

# %%
class1 = df.loc[df.Pclass == 2 ][ "Survived"]
class1_survived = sum(class1)/len(class1)
print(class1_survived)
# Out:
# 0.47282608695652173

# %%
class1 = df.loc[df.Pclass == 3 ][ "Survived"]
class1_survived = sum(class1)/len(class1)
print(class1_survived)
# Out:
# 0.24236252545824846

# %% [markdown]
# ###Age Difference###

# %%
age = df.loc[df.Age == 1 ][ "Survived"]
class1_survived = sum(class1)/len(class1)
print(class1_survived)
# Out:
# 0.24236252545824846

# %%
sns.pairplot(df.drop(['PassengerId'],axis=1),hue='Survived',palette={0: '#e86868', 1: '#72d96c'},corner=True)

# %%
y = df["Survived"]
features = ["Pclass", "Sex", "SibSp", "Parch"]
X,x_test = pd.get_dummies(df[features]), pd.get_dummies(test_df[features])

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
model = RandomForestClassifier(n_estimators= 500, max_depth= 7, random_state= 1)
model.fit(X_train, y_train)
y_pred = model.predict(X_valid)

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_valid, y_pred)

# %%
print(f"Accuracy: {acc * 100:.2f}%")
# Out:
# Accuracy: 76.54%
